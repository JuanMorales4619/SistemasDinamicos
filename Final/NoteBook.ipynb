# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.polynomial.polynomial as pol
import pandas as pd
from math import *
import sympy as sp
from sympy.plotting import plot

# %%
df = pd.read_excel('Book1.xlsx')
df.describe(include='all')
# Out:
#                   x           y
# count    240.000000  240.000000
# mean   17654.642303  116.945833
# std    22044.784006  124.769114
# min        0.000000    0.000000
# 25%        2.979167   31.000000
# 50%        4.665179   68.000000
# 75%    45049.000000  149.250000
# max    45234.000000  547.000000

# %%
xi = np.array(df['x'])
yi = np.array(df['y'])

plt.plot(yi)

# %%
plt.plot(xi)
